# %% [markdown]
# # PREPARACIÓN DE ENTORNO

# %% [markdown]
# ### Importación de librerías

# %%
import imgaug.augmenters as iaa
import json
import keras.backend as K
import matplotlib.pyplot as plt
import numpy as np
import os
import seaborn as sns
import splitfolders
import tensorflow as tf

from classification_models.tfkeras import Classifiers
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils import class_weight

# %% [markdown]
# ### Importación del modelo pre entrenado

# %%
ResNeXt50, preprocess_input = Classifiers.get('vgg16')
base_model = ResNeXt50(include_top=False, input_shape=(224, 224, 3), weights='imagenet')

# %% [markdown]
# ### Definición de variables

# %%
# Ruta del directorio donde están tus datos
input_folder = "/UPC/Tesis/DATASET/Datasetv5"

# Ruta del directorio donde se guardarán los datos divididos
output_folder = "/UPC/Tesis/DATASET/split_data"

model_json_name = "resnext50_model.json"
model_weights_file_name = "resnext50_weights_.hdf5"

# %% [markdown]
# # PREPARACIÓN DE DATOS

# %% [markdown]
# ### División de datos

# %%
# Dividir los datos
#splitfolders.ratio(input_folder, output=output_folder, seed=42, ratio=(.7, .15, .15))

# %% [markdown]
# ### Preprocesamiento de Imágenes

# %% [markdown]
# #### Aumento de datos

# %%
# Definir aumentos personalizados con imgaug
seq = iaa.Sequential([
    iaa.Sometimes(0.5, iaa.Multiply((1.0, 1.196))),               # Brillo
    iaa.Sometimes(0.5, iaa.LinearContrast((0.5, 0.7))),             # Constraste
    iaa.Sometimes(0.5, iaa.AdditiveGaussianNoise(                  # Ruido
        loc=0,
        scale=(0.0, 0.01*255),
        per_channel=0.5
    )),
    iaa.Sometimes(0.5, iaa.GammaContrast((0.97, 1.0))),
    iaa.Sharpen(alpha=(0.1, 0.5), lightness=(0.75, 1.5)),
    iaa.Sometimes(0.5, iaa.WithChannels(0, iaa.Multiply((0.9, 1.1)))),
    iaa.Sometimes(0.5, iaa.WithChannels(1, iaa.Multiply((0.9, 1.1)))),
    iaa.Sometimes(0.5, iaa.WithChannels(2, iaa.Multiply((0.9, 1.1)))),
])

def custom_preprocessing_function(img):
    # Asegurarse de que img es una imagen en el rango [0, 255]
    img = np.array(img, dtype=np.uint8)

    # Aplicar las transformaciones de imgaug
    img = seq.augment_image(img)

    return img

def combined_preprocessing_function(img):
    # Aplicar aumentos de imgaug
    img = custom_preprocessing_function(img)

    # Aplicar preprocesamiento específico del modelo
    img = preprocess_input(img)

    return img

# %%
# Crear un generador de imágenes con aumento de datos
train_datagen = ImageDataGenerator(
    preprocessing_function=combined_preprocessing_function,
    horizontal_flip=True,
    fill_mode='nearest'
)

validation_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=combined_preprocessing_function,
    fill_mode='nearest'
)

# Crear un flujo de imágenes desde el directorio de entrenamiento
train_generator = train_datagen.flow_from_directory(
    '/UPC/Tesis/DATASET/split_data/train',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

# Crear un flujo de imágenes desde el directorio de entrenamiento
validation_generator = validation_datagen.flow_from_directory(
    '/UPC/Tesis/DATASET/split_data/val',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 330 images belonging to 3 classes.
# Found 70 images belonging to 3 classes.

# %%
# Asume que datagen y train_generator ya están definidos como antes

# Obtener un lote de imágenes del generador
imgs, labels = next(train_generator)

# Visualizar algunas imágenes del lote
plt.figure(figsize=(10, 10))

# Valores mínimos y máximos en tus datos
min_val = np.min(imgs)
max_val = np.max(imgs)

# Normalizar las imágenes al rango [0, 1]
normalized_imgs = (imgs - min_val) / (max_val - min_val)

for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(normalized_imgs[i])
    plt.title(f'Label: {labels[i]}')

plt.show()

# %% [markdown]
# ### Equilibrio de clases

# %%
# Obtener las etiquetas del generador
y_labels = train_generator.classes

# Calcular pesos
class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(y_labels), y=y_labels)
class_weights_dict = dict(enumerate(class_weights))

# %% [markdown]
# ### Visualización de estadística de datos

# %%
def plot_data_distribution(directory):
    folders = ['train', 'val', 'test']  # Carpetas de datos
    for folder in folders:
        folder_path = os.path.join(directory, folder)
        classes = os.listdir(folder_path)
        class_counts = [len(os.listdir(os.path.join(folder_path, cls))) for cls in classes]

        plt.figure(figsize=(8, 8))
        plt.pie(class_counts, labels=classes, autopct='%1.1f%%', startangle=140)
        plt.title(f'Distribución de datos en {folder}')
        plt.show()

# Llamar a la función
plot_data_distribution(output_folder)

# %% [markdown]
# # Configurar y Personalizar ResNeXt50

# %%
# Añadir capas personalizadas
x = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(3, activation='softmax')(x)

# Crear el modelo final
model = tf.keras.models.Model(inputs=base_model.input, outputs=x)

model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  data (InputLayer)              [(None, 224, 224, 3  0           []
#                                 )]
#
#  bn_data (BatchNormalization)   (None, 224, 224, 3)  9           ['data[0][0]']
#
#  zero_padding2d_18 (ZeroPadding  (None, 230, 230, 3)  0          ['bn_data[0][0]']
#  2D)
#
#  conv0 (Conv2D)                 (None, 112, 112, 64  9408        ['zero_padding2d_18[0][0]']
#                                 )
#
#  bn0 (BatchNormalization)       (None, 112, 112, 64  256         ['conv0[0][0]']
#                                 )
#
#  relu0 (Activation)             (None, 112, 112, 64  0           ['bn0[0][0]']
#                                 )
#
#  zero_padding2d_19 (ZeroPadding  (None, 114, 114, 64  0          ['relu0[0][0]']
#  2D)                            )
#
#  pooling0 (MaxPooling2D)        (None, 56, 56, 64)   0           ['zero_padding2d_19[0][0]']
#
#  stage1_unit1_conv1 (Conv2D)    (None, 56, 56, 128)  8192        ['pooling0[0][0]']
#
#  stage1_unit1_bn1 (BatchNormali  (None, 56, 56, 128)  512        ['stage1_unit1_conv1[0][0]']
#  zation)
#
#  stage1_unit1_relu1 (Activation  (None, 56, 56, 128)  0          ['stage1_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_20 (ZeroPadding  (None, 58, 58, 128)  0          ['stage1_unit1_relu1[0][0]']
#  2D)
#
#  lambda_512 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_513 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_514 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_515 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_516 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_517 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_518 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_519 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_520 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_521 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_522 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_523 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_524 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_525 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_526 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_527 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_528 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_529 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_530 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_531 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_532 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_533 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_534 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_535 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_536 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_537 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_538 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_539 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_540 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_541 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_542 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_543 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  conv2d_512 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_512[0][0]']
#
#  conv2d_513 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_513[0][0]']
#
#  conv2d_514 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_514[0][0]']
#
#  conv2d_515 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_515[0][0]']
#
#  conv2d_516 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_516[0][0]']
#
#  conv2d_517 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_517[0][0]']
#
#  conv2d_518 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_518[0][0]']
#
#  conv2d_519 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_519[0][0]']
#
#  conv2d_520 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_520[0][0]']
#
#  conv2d_521 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_521[0][0]']
#
#  conv2d_522 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_522[0][0]']
#
#  conv2d_523 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_523[0][0]']
#
#  conv2d_524 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_524[0][0]']
#
#  conv2d_525 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_525[0][0]']
#
#  conv2d_526 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_526[0][0]']
#
#  conv2d_527 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_527[0][0]']
#
#  conv2d_528 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_528[0][0]']
#
#  conv2d_529 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_529[0][0]']
#
#  conv2d_530 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_530[0][0]']
#
#  conv2d_531 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_531[0][0]']
#
#  conv2d_532 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_532[0][0]']
#
#  conv2d_533 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_533[0][0]']
#
#  conv2d_534 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_534[0][0]']
#
#  conv2d_535 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_535[0][0]']
#
#  conv2d_536 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_536[0][0]']
#
#  conv2d_537 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_537[0][0]']
#
#  conv2d_538 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_538[0][0]']
#
#  conv2d_539 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_539[0][0]']
#
#  conv2d_540 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_540[0][0]']
#
#  conv2d_541 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_541[0][0]']
#
#  conv2d_542 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_542[0][0]']
#
#  conv2d_543 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_543[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 56, 56, 128)  0           ['conv2d_512[0][0]',
#                                                                   'conv2d_513[0][0]',
#                                                                   'conv2d_514[0][0]',
#                                                                   'conv2d_515[0][0]',
#                                                                   'conv2d_516[0][0]',
#                                                                   'conv2d_517[0][0]',
#                                                                   'conv2d_518[0][0]',
#                                                                   'conv2d_519[0][0]',
#                                                                   'conv2d_520[0][0]',
#                                                                   'conv2d_521[0][0]',
#                                                                   'conv2d_522[0][0]',
#                                                                   'conv2d_523[0][0]',
#                                                                   'conv2d_524[0][0]',
#                                                                   'conv2d_525[0][0]',
#                                                                   'conv2d_526[0][0]',
#                                                                   'conv2d_527[0][0]',
#                                                                   'conv2d_528[0][0]',
#                                                                   'conv2d_529[0][0]',
#                                                                   'conv2d_530[0][0]',
#                                                                   'conv2d_531[0][0]',
#                                                                   'conv2d_532[0][0]',
#                                                                   'conv2d_533[0][0]',
#                                                                   'conv2d_534[0][0]',
#                                                                   'conv2d_535[0][0]',
#                                                                   'conv2d_536[0][0]',
#                                                                   'conv2d_537[0][0]',
#                                                                   'conv2d_538[0][0]',
#                                                                   'conv2d_539[0][0]',
#                                                                   'conv2d_540[0][0]',
#                                                                   'conv2d_541[0][0]',
#                                                                   'conv2d_542[0][0]',
#                                                                   'conv2d_543[0][0]']
#
#  stage1_unit1_bn2 (BatchNormali  (None, 56, 56, 128)  512        ['concatenate_16[0][0]']
#  zation)
#
#  stage1_unit1_relu2 (Activation  (None, 56, 56, 128)  0          ['stage1_unit1_bn2[0][0]']
#  )
#
#  stage1_unit1_conv3 (Conv2D)    (None, 56, 56, 256)  32768       ['stage1_unit1_relu2[0][0]']
#
#  stage1_unit1_sc (Conv2D)       (None, 56, 56, 256)  16384       ['pooling0[0][0]']
#
#  stage1_unit1_bn3 (BatchNormali  (None, 56, 56, 256)  1024       ['stage1_unit1_conv3[0][0]']
#  zation)
#
#  stage1_unit1_sc_bn (BatchNorma  (None, 56, 56, 256)  1024       ['stage1_unit1_sc[0][0]']
#  lization)
#
#  add_16 (Add)                   (None, 56, 56, 256)  0           ['stage1_unit1_bn3[0][0]',
#                                                                   'stage1_unit1_sc_bn[0][0]']
#
#  stage1_unit1_relu (Activation)  (None, 56, 56, 256)  0          ['add_16[0][0]']
#
#  stage1_unit2_conv1 (Conv2D)    (None, 56, 56, 128)  32768       ['stage1_unit1_relu[0][0]']
#
#  stage1_unit2_bn1 (BatchNormali  (None, 56, 56, 128)  512        ['stage1_unit2_conv1[0][0]']
#  zation)
#
#  stage1_unit2_relu1 (Activation  (None, 56, 56, 128)  0          ['stage1_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_21 (ZeroPadding  (None, 58, 58, 128)  0          ['stage1_unit2_relu1[0][0]']
#  2D)
#
#  lambda_544 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_545 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_546 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_547 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_548 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_549 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_550 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_551 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_552 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_553 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_554 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_555 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_556 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_557 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_558 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_559 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_560 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_561 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_562 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_563 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_564 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_565 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_566 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_567 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_568 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_569 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_570 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_571 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_572 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_573 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_574 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_575 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  conv2d_544 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_544[0][0]']
#
#  conv2d_545 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_545[0][0]']
#
#  conv2d_546 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_546[0][0]']
#
#  conv2d_547 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_547[0][0]']
#
#  conv2d_548 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_548[0][0]']
#
#  conv2d_549 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_549[0][0]']
#
#  conv2d_550 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_550[0][0]']
#
#  conv2d_551 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_551[0][0]']
#
#  conv2d_552 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_552[0][0]']
#
#  conv2d_553 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_553[0][0]']
#
#  conv2d_554 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_554[0][0]']
#
#  conv2d_555 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_555[0][0]']
#
#  conv2d_556 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_556[0][0]']
#
#  conv2d_557 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_557[0][0]']
#
#  conv2d_558 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_558[0][0]']
#
#  conv2d_559 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_559[0][0]']
#
#  conv2d_560 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_560[0][0]']
#
#  conv2d_561 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_561[0][0]']
#
#  conv2d_562 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_562[0][0]']
#
#  conv2d_563 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_563[0][0]']
#
#  conv2d_564 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_564[0][0]']
#
#  conv2d_565 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_565[0][0]']
#
#  conv2d_566 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_566[0][0]']
#
#  conv2d_567 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_567[0][0]']
#
#  conv2d_568 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_568[0][0]']
#
#  conv2d_569 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_569[0][0]']
#
#  conv2d_570 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_570[0][0]']
#
#  conv2d_571 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_571[0][0]']
#
#  conv2d_572 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_572[0][0]']
#
#  conv2d_573 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_573[0][0]']
#
#  conv2d_574 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_574[0][0]']
#
#  conv2d_575 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_575[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 56, 56, 128)  0           ['conv2d_544[0][0]',
#                                                                   'conv2d_545[0][0]',
#                                                                   'conv2d_546[0][0]',
#                                                                   'conv2d_547[0][0]',
#                                                                   'conv2d_548[0][0]',
#                                                                   'conv2d_549[0][0]',
#                                                                   'conv2d_550[0][0]',
#                                                                   'conv2d_551[0][0]',
#                                                                   'conv2d_552[0][0]',
#                                                                   'conv2d_553[0][0]',
#                                                                   'conv2d_554[0][0]',
#                                                                   'conv2d_555[0][0]',
#                                                                   'conv2d_556[0][0]',
#                                                                   'conv2d_557[0][0]',
#                                                                   'conv2d_558[0][0]',
#                                                                   'conv2d_559[0][0]',
#                                                                   'conv2d_560[0][0]',
#                                                                   'conv2d_561[0][0]',
#                                                                   'conv2d_562[0][0]',
#                                                                   'conv2d_563[0][0]',
#                                                                   'conv2d_564[0][0]',
#                                                                   'conv2d_565[0][0]',
#                                                                   'conv2d_566[0][0]',
#                                                                   'conv2d_567[0][0]',
#                                                                   'conv2d_568[0][0]',
#                                                                   'conv2d_569[0][0]',
#                                                                   'conv2d_570[0][0]',
#                                                                   'conv2d_571[0][0]',
#                                                                   'conv2d_572[0][0]',
#                                                                   'conv2d_573[0][0]',
#                                                                   'conv2d_574[0][0]',
#                                                                   'conv2d_575[0][0]']
#
#  stage1_unit2_bn2 (BatchNormali  (None, 56, 56, 128)  512        ['concatenate_17[0][0]']
#  zation)
#
#  stage1_unit2_relu2 (Activation  (None, 56, 56, 128)  0          ['stage1_unit2_bn2[0][0]']
#  )
#
#  stage1_unit2_conv3 (Conv2D)    (None, 56, 56, 256)  32768       ['stage1_unit2_relu2[0][0]']
#
#  stage1_unit2_bn3 (BatchNormali  (None, 56, 56, 256)  1024       ['stage1_unit2_conv3[0][0]']
#  zation)
#
#  add_17 (Add)                   (None, 56, 56, 256)  0           ['stage1_unit2_bn3[0][0]',
#                                                                   'stage1_unit1_relu[0][0]']
#
#  stage1_unit2_relu (Activation)  (None, 56, 56, 256)  0          ['add_17[0][0]']
#
#  stage1_unit3_conv1 (Conv2D)    (None, 56, 56, 128)  32768       ['stage1_unit2_relu[0][0]']
#
#  stage1_unit3_bn1 (BatchNormali  (None, 56, 56, 128)  512        ['stage1_unit3_conv1[0][0]']
#  zation)
#
#  stage1_unit3_relu1 (Activation  (None, 56, 56, 128)  0          ['stage1_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_22 (ZeroPadding  (None, 58, 58, 128)  0          ['stage1_unit3_relu1[0][0]']
#  2D)
#
#  lambda_576 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_577 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_578 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_579 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_580 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_581 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_582 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_583 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_584 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_585 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_586 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_587 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_588 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_589 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_590 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_591 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_592 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_593 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_594 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_595 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_596 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_597 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_598 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_599 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_600 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_601 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_602 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_603 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_604 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_605 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_606 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_607 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  conv2d_576 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_576[0][0]']
#
#  conv2d_577 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_577[0][0]']
# ...
#
#  lambda_1006 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1007 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1008 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1009 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1010 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1011 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1012 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1013 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1014 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1015 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1016 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1017 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1018 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1019 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1020 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1021 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1022 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1023 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  conv2d_992 (Conv2D)            (None, 7, 7, 32)     9216        ['lambda_992[0][0]']
#
#  conv2d_993 (Conv2D)            (None, 7, 7, 32)     9216        ['lambda_993[0][0]']
#
#  conv2d_994 (Conv2D)            (None, 7, 7, 32)     9216        ['lambda_994[0][0]']
#
#  conv2d_995 (Conv2D)            (None, 7, 7, 32)     9216        ['lambda_995[0][0]']
#
#  conv2d_996 (Conv2D)            (None, 7, 7, 32)     9216        ['lambda_996[0][0]']
#
#  conv2d_997 (Conv2D)            (None, 7, 7, 32)     9216        ['lambda_997[0][0]']
#
#  conv2d_998 (Conv2D)            (None, 7, 7, 32)     9216        ['lambda_998[0][0]']
#
#  conv2d_999 (Conv2D)            (None, 7, 7, 32)     9216        ['lambda_999[0][0]']
#
#  conv2d_1000 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1000[0][0]']
#
#  conv2d_1001 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1001[0][0]']
#
#  conv2d_1002 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1002[0][0]']
#
#  conv2d_1003 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1003[0][0]']
#
#  conv2d_1004 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1004[0][0]']
#
#  conv2d_1005 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1005[0][0]']
#
#  conv2d_1006 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1006[0][0]']
#
#  conv2d_1007 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1007[0][0]']
#
#  conv2d_1008 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1008[0][0]']
#
#  conv2d_1009 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1009[0][0]']
#
#  conv2d_1010 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1010[0][0]']
#
#  conv2d_1011 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1011[0][0]']
#
#  conv2d_1012 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1012[0][0]']
#
#  conv2d_1013 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1013[0][0]']
#
#  conv2d_1014 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1014[0][0]']
#
#  conv2d_1015 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1015[0][0]']
#
#  conv2d_1016 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1016[0][0]']
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#  conv2d_1017 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1017[0][0]']
#
#  conv2d_1018 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1018[0][0]']
#
#  conv2d_1019 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1019[0][0]']
#
#  conv2d_1020 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1020[0][0]']
#
#  conv2d_1021 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1021[0][0]']
#
#  conv2d_1022 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1022[0][0]']
#
#  conv2d_1023 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1023[0][0]']
#
#  concatenate_31 (Concatenate)   (None, 7, 7, 1024)   0           ['conv2d_992[0][0]',
#                                                                   'conv2d_993[0][0]',
#                                                                   'conv2d_994[0][0]',
#                                                                   'conv2d_995[0][0]',
#                                                                   'conv2d_996[0][0]',
#                                                                   'conv2d_997[0][0]',
#                                                                   'conv2d_998[0][0]',
#                                                                   'conv2d_999[0][0]',
#                                                                   'conv2d_1000[0][0]',
#                                                                   'conv2d_1001[0][0]',
#                                                                   'conv2d_1002[0][0]',
#                                                                   'conv2d_1003[0][0]',
#                                                                   'conv2d_1004[0][0]',
#                                                                   'conv2d_1005[0][0]',
#                                                                   'conv2d_1006[0][0]',
#                                                                   'conv2d_1007[0][0]',
#                                                                   'conv2d_1008[0][0]',
#                                                                   'conv2d_1009[0][0]',
#                                                                   'conv2d_1010[0][0]',
#                                                                   'conv2d_1011[0][0]',
#                                                                   'conv2d_1012[0][0]',
#                                                                   'conv2d_1013[0][0]',
#                                                                   'conv2d_1014[0][0]',
#                                                                   'conv2d_1015[0][0]',
#                                                                   'conv2d_1016[0][0]',
#                                                                   'conv2d_1017[0][0]',
#                                                                   'conv2d_1018[0][0]',
#                                                                   'conv2d_1019[0][0]',
#                                                                   'conv2d_1020[0][0]',
#                                                                   'conv2d_1021[0][0]',
#                                                                   'conv2d_1022[0][0]',
#                                                                   'conv2d_1023[0][0]']
#
#  stage4_unit3_bn2 (BatchNormali  (None, 7, 7, 1024)  4096        ['concatenate_31[0][0]']
#  zation)
#
#  stage4_unit3_relu2 (Activation  (None, 7, 7, 1024)  0           ['stage4_unit3_bn2[0][0]']
#  )
#
#  stage4_unit3_conv3 (Conv2D)    (None, 7, 7, 2048)   2097152     ['stage4_unit3_relu2[0][0]']
#
#  stage4_unit3_bn3 (BatchNormali  (None, 7, 7, 2048)  8192        ['stage4_unit3_conv3[0][0]']
#  zation)
#
#  add_31 (Add)                   (None, 7, 7, 2048)   0           ['stage4_unit3_bn3[0][0]',
#                                                                   'stage4_unit2_relu[0][0]']
#
#  stage4_unit3_relu (Activation)  (None, 7, 7, 2048)  0           ['add_31[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 2048)        0           ['stage4_unit3_relu[0][0]']
#  obalAveragePooling2D)
#
#  dense_1 (Dense)                (None, 3)            6147        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 23,054,284
# Trainable params: 22,986,054
# Non-trainable params: 68,230
# __________________________________________________________________________________________________

# %% [markdown]
# # Entrenamiento

# %%
# Optimizer
adam = tf.keras.optimizers.Adam(learning_rate=0.0001)

# Compilar el modelo
model.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Usamos la parada temprana para salir del entenamiento si el error de validación
# no decrece después de cierto número de epochs (paciencia)
earlystopping = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 20)

# Guardamos el mejor modelo con menor error de validación
checkpointer = ModelCheckpoint(filepath = model_weights_file_name, verbose = 1, save_best_only=True)

# %%
# Entrenar el modelo
history = model.fit(
    train_generator,
    epochs=35,
    validation_data=validation_generator,
    class_weight=class_weights_dict,
    callbacks=[checkpointer, earlystopping]
)
# Out:
# Epoch 1/45
# 11/11 [==============================] - ETA: 0s - loss: 0.9890 - accuracy: 0.5000
# Epoch 1: val_loss improved from inf to 0.89715, saving model to resnext50_weights_.hdf5
# 11/11 [==============================] - 269s 18s/step - loss: 0.9890 - accuracy: 0.5000 - val_loss: 0.8971 - val_accuracy: 0.5571
# Epoch 2/45
# 11/11 [==============================] - ETA: 0s - loss: 0.5697 - accuracy: 0.7424
# Epoch 2: val_loss did not improve from 0.89715
# 11/11 [==============================] - 154s 15s/step - loss: 0.5697 - accuracy: 0.7424 - val_loss: 1.1739 - val_accuracy: 0.5143
# Epoch 3/45
# 11/11 [==============================] - ETA: 0s - loss: 0.3908 - accuracy: 0.8636
# Epoch 3: val_loss improved from 0.89715 to 0.71449, saving model to resnext50_weights_.hdf5
# 11/11 [==============================] - 153s 14s/step - loss: 0.3908 - accuracy: 0.8636 - val_loss: 0.7145 - val_accuracy: 0.7000
# Epoch 4/45
# 11/11 [==============================] - ETA: 0s - loss: 0.2792 - accuracy: 0.9182
# Epoch 4: val_loss did not improve from 0.71449
# 11/11 [==============================] - 152s 14s/step - loss: 0.2792 - accuracy: 0.9182 - val_loss: 0.7192 - val_accuracy: 0.6429
# Epoch 5/45
# 11/11 [==============================] - ETA: 0s - loss: 0.1850 - accuracy: 0.9636
# Epoch 5: val_loss improved from 0.71449 to 0.65445, saving model to resnext50_weights_.hdf5
# 11/11 [==============================] - 152s 13s/step - loss: 0.1850 - accuracy: 0.9636 - val_loss: 0.6544 - val_accuracy: 0.7000
# Epoch 6/45
# 11/11 [==============================] - ETA: 0s - loss: 0.1294 - accuracy: 0.9758
# Epoch 6: val_loss did not improve from 0.65445
# 11/11 [==============================] - 151s 14s/step - loss: 0.1294 - accuracy: 0.9758 - val_loss: 0.7276 - val_accuracy: 0.7286
# Epoch 7/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0990 - accuracy: 0.9788
# Epoch 7: val_loss improved from 0.65445 to 0.64777, saving model to resnext50_weights_.hdf5
# 11/11 [==============================] - 147s 13s/step - loss: 0.0990 - accuracy: 0.9788 - val_loss: 0.6478 - val_accuracy: 0.7286
# Epoch 8/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0824 - accuracy: 0.9939
# Epoch 8: val_loss improved from 0.64777 to 0.54881, saving model to resnext50_weights_.hdf5
# 11/11 [==============================] - 142s 13s/step - loss: 0.0824 - accuracy: 0.9939 - val_loss: 0.5488 - val_accuracy: 0.7143
# Epoch 9/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0659 - accuracy: 0.9788
# Epoch 9: val_loss did not improve from 0.54881
# 11/11 [==============================] - 148s 13s/step - loss: 0.0659 - accuracy: 0.9788 - val_loss: 0.5552 - val_accuracy: 0.7429
# Epoch 10/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.9970
# Epoch 10: val_loss improved from 0.54881 to 0.39400, saving model to resnext50_weights_.hdf5
# 11/11 [==============================] - 152s 14s/step - loss: 0.0405 - accuracy: 0.9970 - val_loss: 0.3940 - val_accuracy: 0.8143
# Epoch 11/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0468 - accuracy: 0.9939
# Epoch 11: val_loss improved from 0.39400 to 0.30554, saving model to resnext50_weights_.hdf5
# 11/11 [==============================] - 153s 14s/step - loss: 0.0468 - accuracy: 0.9939 - val_loss: 0.3055 - val_accuracy: 0.8143
# Epoch 12/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0314 - accuracy: 0.9970
# Epoch 12: val_loss did not improve from 0.30554
# 11/11 [==============================] - 147s 14s/step - loss: 0.0314 - accuracy: 0.9970 - val_loss: 0.3190 - val_accuracy: 0.8429
# Epoch 13/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 1.0000
# Epoch 13: val_loss improved from 0.30554 to 0.27574, saving model to resnext50_weights_.hdf5
# 11/11 [==============================] - 146s 13s/step - loss: 0.0231 - accuracy: 1.0000 - val_loss: 0.2757 - val_accuracy: 0.8429
# Epoch 14/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0431 - accuracy: 0.9848
# Epoch 14: val_loss improved from 0.27574 to 0.25209, saving model to resnext50_weights_.hdf5
# 11/11 [==============================] - 147s 14s/step - loss: 0.0431 - accuracy: 0.9848 - val_loss: 0.2521 - val_accuracy: 0.8714
# Epoch 15/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0217 - accuracy: 1.0000
# Epoch 15: val_loss improved from 0.25209 to 0.23882, saving model to resnext50_weights_.hdf5
# 11/11 [==============================] - 144s 13s/step - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.2388 - val_accuracy: 0.8571
# Epoch 16/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0225 - accuracy: 0.9970
# Epoch 16: val_loss did not improve from 0.23882
# 11/11 [==============================] - 151s 13s/step - loss: 0.0225 - accuracy: 0.9970 - val_loss: 0.2665 - val_accuracy: 0.8571
# Epoch 17/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0352 - accuracy: 0.9879
# Epoch 17: val_loss did not improve from 0.23882
# 11/11 [==============================] - 165s 15s/step - loss: 0.0352 - accuracy: 0.9879 - val_loss: 0.2977 - val_accuracy: 0.8429
# Epoch 18/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 1.0000
# Epoch 18: val_loss improved from 0.23882 to 0.16910, saving model to resnext50_weights_.hdf5
# 11/11 [==============================] - 169s 15s/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.1691 - val_accuracy: 0.9286
# Epoch 19/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9970
# Epoch 19: val_loss did not improve from 0.16910
# 11/11 [==============================] - 167s 16s/step - loss: 0.0197 - accuracy: 0.9970 - val_loss: 0.2122 - val_accuracy: 0.8857
# Epoch 20/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0270 - accuracy: 0.9970
# Epoch 20: val_loss did not improve from 0.16910
# 11/11 [==============================] - 170s 15s/step - loss: 0.0270 - accuracy: 0.9970 - val_loss: 0.2184 - val_accuracy: 0.8571
# Epoch 21/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 21: val_loss did not improve from 0.16910
# 11/11 [==============================] - 167s 15s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.2250 - val_accuracy: 0.8571
# Epoch 22/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 1.0000
# Epoch 22: val_loss did not improve from 0.16910
# 11/11 [==============================] - 164s 14s/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.2126 - val_accuracy: 0.9143
# Epoch 23/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 23: val_loss did not improve from 0.16910
# 11/11 [==============================] - 169s 15s/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.2037 - val_accuracy: 0.9143
# Epoch 24/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 1.0000
# Epoch 24: val_loss did not improve from 0.16910
# 11/11 [==============================] - 171s 15s/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9143
# Epoch 25/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 1.0000
# Epoch 25: val_loss did not improve from 0.16910
# 11/11 [==============================] - 166s 15s/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.1866 - val_accuracy: 0.9143
# Epoch 26/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 1.0000
# Epoch 26: val_loss did not improve from 0.16910
# 11/11 [==============================] - 166s 15s/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.2350 - val_accuracy: 0.9000
# Epoch 27/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 1.0000
# Epoch 27: val_loss did not improve from 0.16910
# 11/11 [==============================] - 169s 15s/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.2715 - val_accuracy: 0.8571
# Epoch 28/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 28: val_loss did not improve from 0.16910
# 11/11 [==============================] - 170s 16s/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.1989 - val_accuracy: 0.9000
# Epoch 29/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9939
# Epoch 29: val_loss did not improve from 0.16910
# 11/11 [==============================] - 164s 15s/step - loss: 0.0123 - accuracy: 0.9939 - val_loss: 0.2033 - val_accuracy: 0.9000
# Epoch 30/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 30: val_loss did not improve from 0.16910
# 11/11 [==============================] - 167s 15s/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.2023 - val_accuracy: 0.9286
# Epoch 31/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0114 - accuracy: 0.9970
# Epoch 31: val_loss did not improve from 0.16910
# 11/11 [==============================] - 164s 14s/step - loss: 0.0114 - accuracy: 0.9970 - val_loss: 0.2631 - val_accuracy: 0.8714
# Epoch 32/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 32: val_loss did not improve from 0.16910
# 11/11 [==============================] - 169s 15s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2477 - val_accuracy: 0.8714
# Epoch 33/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0098 - accuracy: 0.9970
# Epoch 33: val_loss did not improve from 0.16910
# 11/11 [==============================] - 169s 16s/step - loss: 0.0098 - accuracy: 0.9970 - val_loss: 0.2266 - val_accuracy: 0.8714
# Epoch 34/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9970
# Epoch 34: val_loss did not improve from 0.16910
# 11/11 [==============================] - 168s 15s/step - loss: 0.0070 - accuracy: 0.9970 - val_loss: 0.2194 - val_accuracy: 0.8714
# Epoch 35/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 35: val_loss did not improve from 0.16910
# 11/11 [==============================] - 156s 14s/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.2807 - val_accuracy: 0.8571
# Epoch 36/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 36: val_loss did not improve from 0.16910
# 11/11 [==============================] - 151s 14s/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.2393 - val_accuracy: 0.8714
# Epoch 37/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 37: val_loss did not improve from 0.16910
# 11/11 [==============================] - 146s 13s/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.2193 - val_accuracy: 0.9000
# Epoch 38/45
# 11/11 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9970
# Epoch 38: val_loss did not improve from 0.16910
# 11/11 [==============================] - 150s 13s/step - loss: 0.0103 - accuracy: 0.9970 - val_loss: 0.2507 - val_accuracy: 0.8857
# Epoch 38: early stopping

# %% [markdown]
# # EVALUACION

# %% [markdown]
# ### Graficos de Accuracy y Loss

# %%
fig = plt.figure()
plt.plot(history.history['loss'], color='teal', label='loss')
plt.plot(history.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(history.history['accuracy'], color='teal', label='accuracy')
plt.plot(history.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ### Evaluación con datos de testing

# %%
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=combined_preprocessing_function,
    fill_mode='nearest'
)
# Crear un flujo de imágenes desde el directorio de entrenamiento
test_generator = test_datagen.flow_from_directory(
    '/UPC/Tesis/DATASET/split_data/test',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 74 images belonging to 3 classes.

# %%
# Evaluar el modelo para obtener la pérdida y la precisión (accuracy)
loss, accuracy = model.evaluate(test_generator)
print(f'Test Loss: {loss}')
print(f'Test Accuracy: {accuracy}')
# Out:
# 3/3 [==============================] - 6s 1s/step - loss: 0.3913 - accuracy: 0.8919
# Test Loss: 0.391328901052475
# Test Accuracy: 0.8918918967247009

# %%
# Obtén las predicciones del modelo
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)  # Convierte las predicciones a etiquetas

# Obtén las etiquetas verdaderas
y_true = test_generator.classes
# Out:
# 3/3 [==============================] - 51s 1s/step

# %%
# Obtén la precisión, recall, f1-score, etc.
report = classification_report(y_true, y_pred_classes, target_names=test_generator.class_indices.keys())
print(report)
# Out:
#                  precision    recall  f1-score   support
#
# Pterigión_Grave       0.97      0.90      0.93        39
#  Pterigión_Leve       0.83      0.87      0.85        23
#   Sin_Pterigión       0.79      0.92      0.85        12
#
#        accuracy                           0.89        74
#       macro avg       0.86      0.89      0.88        74
#    weighted avg       0.90      0.89      0.89        74

# %%
# Obtén la matriz de confusión
conf_matrix = confusion_matrix(y_true, y_pred_classes)

# Calcula la sensibilidad y especificidad para cada clase
sensitivity = np.diag(conf_matrix) / np.sum(conf_matrix, axis = 1)
specificity = (np.sum(conf_matrix, axis=0) - np.diag(conf_matrix)) / (np.sum(conf_matrix, axis=0) + np.sum(conf_matrix, axis=1) - 2*np.diag(conf_matrix))

print(f'Sensitivity for each class: {sensitivity}')
print(f'Specificity for each class: {specificity}')
# Out:
# Sensitivity for each class: [0.8974359  0.86956522 0.91666667]
# Specificity for each class: [0.2        0.57142857 0.75      ]

# %%
num_classes = len(np.unique(y_true))  # número de clases
VP = np.diag(conf_matrix)  # Verdaderos Positivos son la diagonal de la matriz de confusión

VN = np.sum(conf_matrix) - np.sum(conf_matrix, axis=0) - np.sum(conf_matrix, axis=1) + VP  # Verdaderos Negativos
FP = np.sum(conf_matrix, axis=0) - VP  # Falsos Positivos
FN = np.sum(conf_matrix, axis=1) - VP  # Falsos Negativos

for i in range(num_classes):
    print(f'Clase {i}: VP={VP[i]}, VN={VN[i]}, FP={FP[i]}, FN={FN[i]}')
# Out:
# Clase 0: VP=35, VN=34, FP=1, FN=4
# Clase 1: VP=20, VN=47, FP=4, FN=3
# Clase 2: VP=11, VN=59, FP=3, FN=1

# %%
plt.figure(figsize=(10,10))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=test_generator.class_indices.keys(),
            yticklabels=test_generator.class_indices.keys())
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# # GUARDAR EL MODELO

# %%
model_json = model.to_json()
with open(model_json_name,"w") as json_file:
    json_file.write(model_json)

# %%
with open(model_json_name, 'r') as json_file:
    json_savedModel= json_file.read()

# Cargamos la arquitectura del modelo
model = tf.keras.models.model_from_json(json_savedModel)
model.load_weights(model_weights_file_name)
model.compile(optimizer = 'SGD', loss = "categorical_crossentropy", metrics = ["accuracy"])

# %% [markdown]
# # DESPLEGAR EL MODELO

# %%
def deploy(directory, model_file, model_version):
    MODEL_DIR = directory
    version = model_version

    # Juntamos el directorio del temp model con la versión elegida
    # El resultado será = '\tmp\version number'
    export_path = os.path.join(MODEL_DIR, version)
    print('export_path = {}\n'.format(export_path))

    # Guardemos el modelo con saved_model.save
    # Si el directorio existe, debemos borrarlo con '!rm'
    # rm elimina cada fichero especificado usando la consola de comandos.

    if os.path.isdir(export_path):
        print('\nAlready saved a model, cleaning up\n')
        # !rm -r {export_path}

    tf.saved_model.save(model_file, export_path)

    os.environ["MODEL_DIR"] = MODEL_DIR
