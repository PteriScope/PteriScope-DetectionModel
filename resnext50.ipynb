# %% [markdown]
# # PREPARACIÓN DE ENTORNO

# %%
import imgaug.augmenters as iaa
import json
import keras.backend as K
import matplotlib.pyplot as plt
import numpy as np
import os
import seaborn as sns
import splitfolders
import tensorflow as tf

from classification_models.tfkeras import Classifiers
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils import class_weight

# %%
ResNeXt50, preprocess_input = Classifiers.get('resnext50')
base_model = ResNeXt50(include_top=False, input_shape=(224, 224, 3), weights='imagenet')

# %% [markdown]
# # PREPARACIÓN DE DATOS

# %% [markdown]
# ### División de datos

# %%
# Ruta del directorio donde están tus datos
#input_folder = "/UPC/Tesis/DATASET/Datasetv5"

# Ruta del directorio donde se guardarán los datos divididos
#output_folder = "/UPC/Tesis/DATASET/split_data"

# Dividir los datos
#splitfolders.ratio(input_folder, output=output_folder, seed=42, ratio=(.7, .15, .15))

# %% [markdown]
# ### Preprocesamiento de Imágenes

# %% [markdown]
# #### Aumento de datos

# %%
# Definir aumentos personalizados con imgaug
seq = iaa.Sequential([
    iaa.Multiply((1.0, 1.196)),               # Brillo
    iaa.LinearContrast((0.5, 0.7)),             # Constraste
    iaa.AdditiveGaussianNoise(                  # Ruido
        loc=0,
        scale=(0.0, 0.01*255),
        per_channel=0.5
    ),
    iaa.GammaContrast((0.97, 1.0)),
    iaa.Sharpen(alpha=(0.1, 0.5), lightness=(0.75, 1.5)),
    iaa.WithChannels(0, iaa.Multiply((0.9, 1.1))),
    iaa.WithChannels(1, iaa.Multiply((0.9, 1.1))),
    iaa.WithChannels(2, iaa.Multiply((0.9, 1.1))),
])

def custom_preprocessing_function(img):
    # Asegurarse de que img es una imagen en el rango [0, 255]
    img = np.array(img, dtype=np.uint8)

    # Aplicar las transformaciones de imgaug
    img = seq.augment_image(img)

    # Reescalar los valores de los píxeles a [0, 1]
    #img = img / 255.0

    return img

def combined_preprocessing_function(img):
    # Aplicar aumentos de imgaug
    img = custom_preprocessing_function(img)

    # Aplicar preprocesamiento específico del modelo
    img = preprocess_input(img)

    return img

# %%
# Crear un generador de imágenes con aumento de datos
train_datagen = ImageDataGenerator(
    preprocessing_function=combined_preprocessing_function,
    horizontal_flip=True,
    fill_mode='nearest'
)

validation_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=combined_preprocessing_function,
    fill_mode='nearest'
)

# Crear un flujo de imágenes desde el directorio de entrenamiento
train_generator = train_datagen.flow_from_directory(
    '/UPC/Tesis/DATASET/split_data/train',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

# Crear un flujo de imágenes desde el directorio de entrenamiento
validation_generator = validation_datagen.flow_from_directory(
    '/UPC/Tesis/DATASET/split_data/val',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 330 images belonging to 3 classes.
# Found 70 images belonging to 3 classes.

# %%
# Asume que datagen y train_generator ya están definidos como antes

# Obtener un lote de imágenes del generador
imgs, labels = next(train_generator)

# Visualizar algunas imágenes del lote
plt.figure(figsize=(10, 10))

# Valores mínimos y máximos en tus datos
min_val = np.min(imgs)
max_val = np.max(imgs)

# Normalizar las imágenes al rango [0, 1]
normalized_imgs = (imgs - min_val) / (max_val - min_val)

for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(normalized_imgs[i])
    plt.title(f'Label: {labels[i]}')

plt.show()

# %% [markdown]
# ### Equilibrio de clases

# %%
# Obtener las etiquetas del generador
y_labels = train_generator.classes

# Calcular pesos
class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(y_labels), y=y_labels)
class_weights_dict = dict(enumerate(class_weights))

# %% [markdown]
# # Configurar y Personalizar ResNeXt50

# %%
# Añadir capas personalizadas
x = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(3, activation='softmax')(x)

# Crear el modelo final
model = tf.keras.models.Model(inputs=base_model.input, outputs=x)

model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  data (InputLayer)              [(None, 224, 224, 3  0           []
#                                 )]
#
#  bn_data (BatchNormalization)   (None, 224, 224, 3)  9           ['data[0][0]']
#
#  zero_padding2d_18 (ZeroPadding  (None, 230, 230, 3)  0          ['bn_data[0][0]']
#  2D)
#
#  conv0 (Conv2D)                 (None, 112, 112, 64  9408        ['zero_padding2d_18[0][0]']
#                                 )
#
#  bn0 (BatchNormalization)       (None, 112, 112, 64  256         ['conv0[0][0]']
#                                 )
#
#  relu0 (Activation)             (None, 112, 112, 64  0           ['bn0[0][0]']
#                                 )
#
#  zero_padding2d_19 (ZeroPadding  (None, 114, 114, 64  0          ['relu0[0][0]']
#  2D)                            )
#
#  pooling0 (MaxPooling2D)        (None, 56, 56, 64)   0           ['zero_padding2d_19[0][0]']
#
#  stage1_unit1_conv1 (Conv2D)    (None, 56, 56, 128)  8192        ['pooling0[0][0]']
#
#  stage1_unit1_bn1 (BatchNormali  (None, 56, 56, 128)  512        ['stage1_unit1_conv1[0][0]']
#  zation)
#
#  stage1_unit1_relu1 (Activation  (None, 56, 56, 128)  0          ['stage1_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_20 (ZeroPadding  (None, 58, 58, 128)  0          ['stage1_unit1_relu1[0][0]']
#  2D)
#
#  lambda_528 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_529 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_530 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_531 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_532 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_533 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_534 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_535 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_536 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_537 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_538 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_539 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_540 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_541 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_542 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_543 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_544 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_545 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_546 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_547 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_548 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_549 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_550 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_551 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_552 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_553 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_554 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_555 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_556 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_557 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_558 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  lambda_559 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_20[0][0]']
#
#  conv2d_581 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_528[0][0]']
#
#  conv2d_582 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_529[0][0]']
#
#  conv2d_583 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_530[0][0]']
#
#  conv2d_584 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_531[0][0]']
#
#  conv2d_585 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_532[0][0]']
#
#  conv2d_586 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_533[0][0]']
#
#  conv2d_587 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_534[0][0]']
#
#  conv2d_588 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_535[0][0]']
#
#  conv2d_589 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_536[0][0]']
#
#  conv2d_590 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_537[0][0]']
#
#  conv2d_591 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_538[0][0]']
#
#  conv2d_592 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_539[0][0]']
#
#  conv2d_593 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_540[0][0]']
#
#  conv2d_594 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_541[0][0]']
#
#  conv2d_595 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_542[0][0]']
#
#  conv2d_596 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_543[0][0]']
#
#  conv2d_597 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_544[0][0]']
#
#  conv2d_598 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_545[0][0]']
#
#  conv2d_599 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_546[0][0]']
#
#  conv2d_600 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_547[0][0]']
#
#  conv2d_601 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_548[0][0]']
#
#  conv2d_602 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_549[0][0]']
#
#  conv2d_603 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_550[0][0]']
#
#  conv2d_604 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_551[0][0]']
#
#  conv2d_605 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_552[0][0]']
#
#  conv2d_606 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_553[0][0]']
#
#  conv2d_607 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_554[0][0]']
#
#  conv2d_608 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_555[0][0]']
#
#  conv2d_609 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_556[0][0]']
#
#  conv2d_610 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_557[0][0]']
#
#  conv2d_611 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_558[0][0]']
#
#  conv2d_612 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_559[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 56, 56, 128)  0           ['conv2d_581[0][0]',
#                                                                   'conv2d_582[0][0]',
#                                                                   'conv2d_583[0][0]',
#                                                                   'conv2d_584[0][0]',
#                                                                   'conv2d_585[0][0]',
#                                                                   'conv2d_586[0][0]',
#                                                                   'conv2d_587[0][0]',
#                                                                   'conv2d_588[0][0]',
#                                                                   'conv2d_589[0][0]',
#                                                                   'conv2d_590[0][0]',
#                                                                   'conv2d_591[0][0]',
#                                                                   'conv2d_592[0][0]',
#                                                                   'conv2d_593[0][0]',
#                                                                   'conv2d_594[0][0]',
#                                                                   'conv2d_595[0][0]',
#                                                                   'conv2d_596[0][0]',
#                                                                   'conv2d_597[0][0]',
#                                                                   'conv2d_598[0][0]',
#                                                                   'conv2d_599[0][0]',
#                                                                   'conv2d_600[0][0]',
#                                                                   'conv2d_601[0][0]',
#                                                                   'conv2d_602[0][0]',
#                                                                   'conv2d_603[0][0]',
#                                                                   'conv2d_604[0][0]',
#                                                                   'conv2d_605[0][0]',
#                                                                   'conv2d_606[0][0]',
#                                                                   'conv2d_607[0][0]',
#                                                                   'conv2d_608[0][0]',
#                                                                   'conv2d_609[0][0]',
#                                                                   'conv2d_610[0][0]',
#                                                                   'conv2d_611[0][0]',
#                                                                   'conv2d_612[0][0]']
#
#  stage1_unit1_bn2 (BatchNormali  (None, 56, 56, 128)  512        ['concatenate_16[0][0]']
#  zation)
#
#  stage1_unit1_relu2 (Activation  (None, 56, 56, 128)  0          ['stage1_unit1_bn2[0][0]']
#  )
#
#  stage1_unit1_conv3 (Conv2D)    (None, 56, 56, 256)  32768       ['stage1_unit1_relu2[0][0]']
#
#  stage1_unit1_sc (Conv2D)       (None, 56, 56, 256)  16384       ['pooling0[0][0]']
#
#  stage1_unit1_bn3 (BatchNormali  (None, 56, 56, 256)  1024       ['stage1_unit1_conv3[0][0]']
#  zation)
#
#  stage1_unit1_sc_bn (BatchNorma  (None, 56, 56, 256)  1024       ['stage1_unit1_sc[0][0]']
#  lization)
#
#  add_16 (Add)                   (None, 56, 56, 256)  0           ['stage1_unit1_bn3[0][0]',
#                                                                   'stage1_unit1_sc_bn[0][0]']
#
#  stage1_unit1_relu (Activation)  (None, 56, 56, 256)  0          ['add_16[0][0]']
#
#  stage1_unit2_conv1 (Conv2D)    (None, 56, 56, 128)  32768       ['stage1_unit1_relu[0][0]']
#
#  stage1_unit2_bn1 (BatchNormali  (None, 56, 56, 128)  512        ['stage1_unit2_conv1[0][0]']
#  zation)
#
#  stage1_unit2_relu1 (Activation  (None, 56, 56, 128)  0          ['stage1_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_21 (ZeroPadding  (None, 58, 58, 128)  0          ['stage1_unit2_relu1[0][0]']
#  2D)
#
#  lambda_560 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_561 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_562 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_563 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_564 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_565 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_566 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_567 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_568 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_569 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_570 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_571 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_572 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_573 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_574 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_575 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_576 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_577 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_578 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_579 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_580 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_581 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_582 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_583 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_584 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_585 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_586 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_587 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_588 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_589 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_590 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  lambda_591 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_21[0][0]']
#
#  conv2d_613 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_560[0][0]']
#
#  conv2d_614 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_561[0][0]']
#
#  conv2d_615 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_562[0][0]']
#
#  conv2d_616 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_563[0][0]']
#
#  conv2d_617 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_564[0][0]']
#
#  conv2d_618 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_565[0][0]']
#
#  conv2d_619 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_566[0][0]']
#
#  conv2d_620 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_567[0][0]']
#
#  conv2d_621 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_568[0][0]']
#
#  conv2d_622 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_569[0][0]']
#
#  conv2d_623 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_570[0][0]']
#
#  conv2d_624 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_571[0][0]']
#
#  conv2d_625 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_572[0][0]']
#
#  conv2d_626 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_573[0][0]']
#
#  conv2d_627 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_574[0][0]']
#
#  conv2d_628 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_575[0][0]']
#
#  conv2d_629 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_576[0][0]']
#
#  conv2d_630 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_577[0][0]']
#
#  conv2d_631 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_578[0][0]']
#
#  conv2d_632 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_579[0][0]']
#
#  conv2d_633 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_580[0][0]']
#
#  conv2d_634 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_581[0][0]']
#
#  conv2d_635 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_582[0][0]']
#
#  conv2d_636 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_583[0][0]']
#
#  conv2d_637 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_584[0][0]']
#
#  conv2d_638 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_585[0][0]']
#
#  conv2d_639 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_586[0][0]']
#
#  conv2d_640 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_587[0][0]']
#
#  conv2d_641 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_588[0][0]']
#
#  conv2d_642 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_589[0][0]']
#
#  conv2d_643 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_590[0][0]']
#
#  conv2d_644 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_591[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 56, 56, 128)  0           ['conv2d_613[0][0]',
#                                                                   'conv2d_614[0][0]',
#                                                                   'conv2d_615[0][0]',
#                                                                   'conv2d_616[0][0]',
#                                                                   'conv2d_617[0][0]',
#                                                                   'conv2d_618[0][0]',
#                                                                   'conv2d_619[0][0]',
#                                                                   'conv2d_620[0][0]',
#                                                                   'conv2d_621[0][0]',
#                                                                   'conv2d_622[0][0]',
#                                                                   'conv2d_623[0][0]',
#                                                                   'conv2d_624[0][0]',
#                                                                   'conv2d_625[0][0]',
#                                                                   'conv2d_626[0][0]',
#                                                                   'conv2d_627[0][0]',
#                                                                   'conv2d_628[0][0]',
#                                                                   'conv2d_629[0][0]',
#                                                                   'conv2d_630[0][0]',
#                                                                   'conv2d_631[0][0]',
#                                                                   'conv2d_632[0][0]',
#                                                                   'conv2d_633[0][0]',
#                                                                   'conv2d_634[0][0]',
#                                                                   'conv2d_635[0][0]',
#                                                                   'conv2d_636[0][0]',
#                                                                   'conv2d_637[0][0]',
#                                                                   'conv2d_638[0][0]',
#                                                                   'conv2d_639[0][0]',
#                                                                   'conv2d_640[0][0]',
#                                                                   'conv2d_641[0][0]',
#                                                                   'conv2d_642[0][0]',
#                                                                   'conv2d_643[0][0]',
#                                                                   'conv2d_644[0][0]']
#
#  stage1_unit2_bn2 (BatchNormali  (None, 56, 56, 128)  512        ['concatenate_17[0][0]']
#  zation)
#
#  stage1_unit2_relu2 (Activation  (None, 56, 56, 128)  0          ['stage1_unit2_bn2[0][0]']
#  )
#
#  stage1_unit2_conv3 (Conv2D)    (None, 56, 56, 256)  32768       ['stage1_unit2_relu2[0][0]']
#
#  stage1_unit2_bn3 (BatchNormali  (None, 56, 56, 256)  1024       ['stage1_unit2_conv3[0][0]']
#  zation)
#
#  add_17 (Add)                   (None, 56, 56, 256)  0           ['stage1_unit2_bn3[0][0]',
#                                                                   'stage1_unit1_relu[0][0]']
#
#  stage1_unit2_relu (Activation)  (None, 56, 56, 256)  0          ['add_17[0][0]']
#
#  stage1_unit3_conv1 (Conv2D)    (None, 56, 56, 128)  32768       ['stage1_unit2_relu[0][0]']
#
#  stage1_unit3_bn1 (BatchNormali  (None, 56, 56, 128)  512        ['stage1_unit3_conv1[0][0]']
#  zation)
#
#  stage1_unit3_relu1 (Activation  (None, 56, 56, 128)  0          ['stage1_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_22 (ZeroPadding  (None, 58, 58, 128)  0          ['stage1_unit3_relu1[0][0]']
#  2D)
#
#  lambda_592 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_593 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_594 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_595 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_596 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_597 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_598 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_599 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_600 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_601 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_602 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_603 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_604 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_605 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_606 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_607 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_608 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_609 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_610 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_611 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_612 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_613 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_614 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_615 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_616 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_617 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_618 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_619 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_620 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_621 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_622 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  lambda_623 (Lambda)            (None, 58, 58, 4)    0           ['zero_padding2d_22[0][0]']
#
#  conv2d_645 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_592[0][0]']
#
#  conv2d_646 (Conv2D)            (None, 56, 56, 4)    144         ['lambda_593[0][0]']
# ...
#
#  lambda_1021 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1022 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1023 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1024 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1025 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1026 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1027 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1028 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1029 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1030 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1031 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1032 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1033 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1034 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1035 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1036 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1037 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1038 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  lambda_1039 (Lambda)           (None, 9, 9, 32)     0           ['zero_padding2d_35[0][0]']
#
#  conv2d_1061 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1008[0][0]']
#
#  conv2d_1062 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1009[0][0]']
#
#  conv2d_1063 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1010[0][0]']
#
#  conv2d_1064 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1011[0][0]']
#
#  conv2d_1065 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1012[0][0]']
#
#  conv2d_1066 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1013[0][0]']
#
#  conv2d_1067 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1014[0][0]']
#
#  conv2d_1068 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1015[0][0]']
#
#  conv2d_1069 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1016[0][0]']
#
#  conv2d_1070 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1017[0][0]']
#
#  conv2d_1071 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1018[0][0]']
#
#  conv2d_1072 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1019[0][0]']
#
#  conv2d_1073 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1020[0][0]']
#
#  conv2d_1074 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1021[0][0]']
#
#  conv2d_1075 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1022[0][0]']
#
#  conv2d_1076 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1023[0][0]']
#
#  conv2d_1077 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1024[0][0]']
#
#  conv2d_1078 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1025[0][0]']
#
#  conv2d_1079 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1026[0][0]']
#
#  conv2d_1080 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1027[0][0]']
#
#  conv2d_1081 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1028[0][0]']
#
#  conv2d_1082 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1029[0][0]']
#
#  conv2d_1083 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1030[0][0]']
#
#  conv2d_1084 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1031[0][0]']
#
#  conv2d_1085 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1032[0][0]']
#
#  conv2d_1086 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1033[0][0]']
#
#  conv2d_1087 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1034[0][0]']
#
#  conv2d_1088 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1035[0][0]']
#
#  conv2d_1089 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1036[0][0]']
#
#  conv2d_1090 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1037[0][0]']
#
#  conv2d_1091 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1038[0][0]']
#
#  conv2d_1092 (Conv2D)           (None, 7, 7, 32)     9216        ['lambda_1039[0][0]']
#
#  concatenate_31 (Concatenate)   (None, 7, 7, 1024)   0           ['conv2d_1061[0][0]',
#                                                                   'conv2d_1062[0][0]',
#                                                                   'conv2d_1063[0][0]',
#                                                                   'conv2d_1064[0][0]',
#                                                                   'conv2d_1065[0][0]',
#                                                                   'conv2d_1066[0][0]',
#                                                                   'conv2d_1067[0][0]',
#                                                                   'conv2d_1068[0][0]',
#                                                                   'conv2d_1069[0][0]',
#                                                                   'conv2d_1070[0][0]',
#                                                                   'conv2d_1071[0][0]',
#                                                                   'conv2d_1072[0][0]',
#                                                                   'conv2d_1073[0][0]',
#                                                                   'conv2d_1074[0][0]',
#                                                                   'conv2d_1075[0][0]',
#                                                                   'conv2d_1076[0][0]',
#                                                                   'conv2d_1077[0][0]',
#                                                                   'conv2d_1078[0][0]',
#                                                                   'conv2d_1079[0][0]',
#                                                                   'conv2d_1080[0][0]',
#                                                                   'conv2d_1081[0][0]',
#                                                                   'conv2d_1082[0][0]',
#                                                                   'conv2d_1083[0][0]',
#                                                                   'conv2d_1084[0][0]',
#                                                                   'conv2d_1085[0][0]',
#                                                                   'conv2d_1086[0][0]',
#                                                                   'conv2d_1087[0][0]',
#                                                                   'conv2d_1088[0][0]',
#                                                                   'conv2d_1089[0][0]',
#                                                                   'conv2d_1090[0][0]',
#                                                                   'conv2d_1091[0][0]',
#                                                                   'conv2d_1092[0][0]']
#
#  stage4_unit3_bn2 (BatchNormali  (None, 7, 7, 1024)  4096        ['concatenate_31[0][0]']
#  zation)
#
#  stage4_unit3_relu2 (Activation  (None, 7, 7, 1024)  0           ['stage4_unit3_bn2[0][0]']
#  )
#
#  stage4_unit3_conv3 (Conv2D)    (None, 7, 7, 2048)   2097152     ['stage4_unit3_relu2[0][0]']
#
#  stage4_unit3_bn3 (BatchNormali  (None, 7, 7, 2048)  8192        ['stage4_unit3_conv3[0][0]']
#  zation)
#
#  add_31 (Add)                   (None, 7, 7, 2048)   0           ['stage4_unit3_bn3[0][0]',
#                                                                   'stage4_unit2_relu[0][0]']
#
#  stage4_unit3_relu (Activation)  (None, 7, 7, 2048)  0           ['add_31[0][0]']
#
#  global_average_pooling2d_16 (G  (None, 2048)        0           ['stage4_unit3_relu[0][0]']
#  lobalAveragePooling2D)
#
#  dense (Dense)                  (None, 3)            6147        ['global_average_pooling2d_16[0][
#                                                                  0]']
#
# ==================================================================================================
# Total params: 23,054,284
# Trainable params: 22,986,054
# Non-trainable params: 68,230
# __________________________________________________________________________________________________

# %% [markdown]
# # Entrenamiento

# %%
# Optimizer
adam = tf.keras.optimizers.Adam(learning_rate=0.0001)

# Compilar el modelo
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model_json_name = "resnext50_model.json"
model_weights_file_name = "resnext50_weights_.hdf5"

# Usamos la parada temprana para salir del entenamiento si el error de validación
# no decrece después de cierto número de epochs (paciencia)
earlystopping = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 20)

# Guardamos el mejor modelo con menor error de validación
checkpointer = ModelCheckpoint(filepath = model_weights_file_name, verbose = 1, save_best_only=True)

# %%
# Entrenar el modelo
history = model.fit(
    train_generator,
    epochs=35,
    validation_data=validation_generator,
    class_weight=class_weights_dict,
    callbacks=[checkpointer, earlystopping]
)
# Out:
# Epoch 1/35
# 11/11 [==============================] - ETA: 0s - loss: 0.8683 - accuracy: 0.6152
# Epoch 1: val_loss improved from inf to 2.13398, saving model to resnext50_weights_.hdf5
# 11/11 [==============================] - 236s 18s/step - loss: 0.8683 - accuracy: 0.6152 - val_loss: 2.1340 - val_accuracy: 0.5571
# Epoch 2/35
# 11/11 [==============================] - ETA: 0s - loss: 0.3572 - accuracy: 0.8303
# Epoch 2: val_loss did not improve from 2.13398
# 11/11 [==============================] - 173s 15s/step - loss: 0.3572 - accuracy: 0.8303 - val_loss: 3.1512 - val_accuracy: 0.5429
# Epoch 3/35
# 11/11 [==============================] - ETA: 0s - loss: 0.1609 - accuracy: 0.9364
# Epoch 3: val_loss did not improve from 2.13398
# 11/11 [==============================] - 165s 15s/step - loss: 0.1609 - accuracy: 0.9364 - val_loss: 2.2606 - val_accuracy: 0.5429
# Epoch 4/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0670 - accuracy: 0.9818
# Epoch 4: val_loss did not improve from 2.13398
# 11/11 [==============================] - 164s 15s/step - loss: 0.0670 - accuracy: 0.9818 - val_loss: 2.5624 - val_accuracy: 0.5571
# Epoch 5/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0349 - accuracy: 0.9939
# Epoch 5: val_loss did not improve from 2.13398
# 11/11 [==============================] - 170s 15s/step - loss: 0.0349 - accuracy: 0.9939 - val_loss: 2.9944 - val_accuracy: 0.5857
# Epoch 6/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0617 - accuracy: 0.9758
# Epoch 6: val_loss did not improve from 2.13398
# 11/11 [==============================] - 172s 15s/step - loss: 0.0617 - accuracy: 0.9758 - val_loss: 2.1991 - val_accuracy: 0.5714
# Epoch 7/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0424 - accuracy: 0.9818
# Epoch 7: val_loss improved from 2.13398 to 1.01942, saving model to resnext50_weights_.hdf5
# 11/11 [==============================] - 170s 15s/step - loss: 0.0424 - accuracy: 0.9818 - val_loss: 1.0194 - val_accuracy: 0.8000
# Epoch 8/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9939
# Epoch 8: val_loss did not improve from 1.01942
# 11/11 [==============================] - 153s 14s/step - loss: 0.0136 - accuracy: 0.9939 - val_loss: 1.2332 - val_accuracy: 0.7429
# Epoch 9/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9879
# Epoch 9: val_loss did not improve from 1.01942
# 11/11 [==============================] - 155s 14s/step - loss: 0.0223 - accuracy: 0.9879 - val_loss: 1.3567 - val_accuracy: 0.7000
# Epoch 10/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9970
# Epoch 10: val_loss improved from 1.01942 to 0.92423, saving model to resnext50_weights_.hdf5
# 11/11 [==============================] - 159s 15s/step - loss: 0.0176 - accuracy: 0.9970 - val_loss: 0.9242 - val_accuracy: 0.7571
# Epoch 11/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0718 - accuracy: 0.9818
# Epoch 11: val_loss improved from 0.92423 to 0.71772, saving model to resnext50_weights_.hdf5
# 11/11 [==============================] - 161s 14s/step - loss: 0.0718 - accuracy: 0.9818 - val_loss: 0.7177 - val_accuracy: 0.8143
# Epoch 12/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0730 - accuracy: 0.9788
# Epoch 12: val_loss did not improve from 0.71772
# 11/11 [==============================] - 154s 14s/step - loss: 0.0730 - accuracy: 0.9788 - val_loss: 0.8931 - val_accuracy: 0.7571
# Epoch 13/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0880 - accuracy: 0.9788
# Epoch 13: val_loss improved from 0.71772 to 0.28812, saving model to resnext50_weights_.hdf5
# 11/11 [==============================] - 163s 15s/step - loss: 0.0880 - accuracy: 0.9788 - val_loss: 0.2881 - val_accuracy: 0.9000
# Epoch 14/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0500 - accuracy: 0.9697
# Epoch 14: val_loss did not improve from 0.28812
# 11/11 [==============================] - 154s 14s/step - loss: 0.0500 - accuracy: 0.9697 - val_loss: 0.6524 - val_accuracy: 0.8143
# Epoch 15/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9939
# Epoch 15: val_loss did not improve from 0.28812
# 11/11 [==============================] - 151s 13s/step - loss: 0.0207 - accuracy: 0.9939 - val_loss: 0.8127 - val_accuracy: 0.7857
# Epoch 16/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 1.0000
# Epoch 16: val_loss did not improve from 0.28812
# 11/11 [==============================] - 152s 14s/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.9110 - val_accuracy: 0.7571
# Epoch 17/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9970
# Epoch 17: val_loss did not improve from 0.28812
# 11/11 [==============================] - 156s 14s/step - loss: 0.0143 - accuracy: 0.9970 - val_loss: 0.7955 - val_accuracy: 0.8000
# Epoch 18/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.9939
# Epoch 18: val_loss improved from 0.28812 to 0.26880, saving model to resnext50_weights_.hdf5
# 11/11 [==============================] - 164s 15s/step - loss: 0.0227 - accuracy: 0.9939 - val_loss: 0.2688 - val_accuracy: 0.9286
# Epoch 19/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9970
# Epoch 19: val_loss did not improve from 0.26880
# 11/11 [==============================] - 151s 13s/step - loss: 0.0109 - accuracy: 0.9970 - val_loss: 0.3687 - val_accuracy: 0.9000
# Epoch 20/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9879
# Epoch 20: val_loss did not improve from 0.26880
# 11/11 [==============================] - 151s 13s/step - loss: 0.0180 - accuracy: 0.9879 - val_loss: 0.4890 - val_accuracy: 0.8571
# Epoch 21/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 21: val_loss did not improve from 0.26880
# 11/11 [==============================] - 150s 13s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.3214 - val_accuracy: 0.8571
# Epoch 22/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9939
# Epoch 22: val_loss improved from 0.26880 to 0.13912, saving model to resnext50_weights_.hdf5
# 11/11 [==============================] - 163s 15s/step - loss: 0.0081 - accuracy: 0.9939 - val_loss: 0.1391 - val_accuracy: 0.9429
# Epoch 23/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9970
# Epoch 23: val_loss did not improve from 0.13912
# 11/11 [==============================] - 155s 14s/step - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.3326 - val_accuracy: 0.9143
# Epoch 24/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0196 - accuracy: 0.9879
# Epoch 24: val_loss did not improve from 0.13912
# 11/11 [==============================] - 154s 14s/step - loss: 0.0196 - accuracy: 0.9879 - val_loss: 0.2988 - val_accuracy: 0.9429
# Epoch 25/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0988 - accuracy: 0.9727
# Epoch 25: val_loss did not improve from 0.13912
# 11/11 [==============================] - 151s 13s/step - loss: 0.0988 - accuracy: 0.9727 - val_loss: 0.6434 - val_accuracy: 0.8286
# Epoch 26/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9879
# Epoch 26: val_loss did not improve from 0.13912
# 11/11 [==============================] - 151s 14s/step - loss: 0.0241 - accuracy: 0.9879 - val_loss: 0.8738 - val_accuracy: 0.8000
# Epoch 27/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0811 - accuracy: 0.9667
# Epoch 27: val_loss did not improve from 0.13912
# 11/11 [==============================] - 153s 14s/step - loss: 0.0811 - accuracy: 0.9667 - val_loss: 0.7190 - val_accuracy: 0.8000
# Epoch 28/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0352 - accuracy: 0.9848
# Epoch 28: val_loss did not improve from 0.13912
# 11/11 [==============================] - 149s 13s/step - loss: 0.0352 - accuracy: 0.9848 - val_loss: 0.5113 - val_accuracy: 0.8429
# Epoch 29/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0304 - accuracy: 0.9970
# Epoch 29: val_loss did not improve from 0.13912
# 11/11 [==============================] - 153s 14s/step - loss: 0.0304 - accuracy: 0.9970 - val_loss: 0.3247 - val_accuracy: 0.9143
# Epoch 30/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0528 - accuracy: 0.9758
# Epoch 30: val_loss did not improve from 0.13912
# 11/11 [==============================] - 152s 13s/step - loss: 0.0528 - accuracy: 0.9758 - val_loss: 0.1778 - val_accuracy: 0.9714
# Epoch 31/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0387 - accuracy: 0.9848
# Epoch 31: val_loss did not improve from 0.13912
# 11/11 [==============================] - 151s 14s/step - loss: 0.0387 - accuracy: 0.9848 - val_loss: 0.1745 - val_accuracy: 0.9429
# Epoch 32/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9939
# Epoch 32: val_loss improved from 0.13912 to 0.12278, saving model to resnext50_weights_.hdf5
# 11/11 [==============================] - 161s 14s/step - loss: 0.0200 - accuracy: 0.9939 - val_loss: 0.1228 - val_accuracy: 0.9429
# Epoch 33/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0692 - accuracy: 0.9848
# Epoch 33: val_loss did not improve from 0.12278
# 11/11 [==============================] - 151s 13s/step - loss: 0.0692 - accuracy: 0.9848 - val_loss: 0.2336 - val_accuracy: 0.9286
# Epoch 34/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.9879
# Epoch 34: val_loss did not improve from 0.12278
# 11/11 [==============================] - 149s 13s/step - loss: 0.0260 - accuracy: 0.9879 - val_loss: 0.4090 - val_accuracy: 0.9286
# Epoch 35/35
# 11/11 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9879
# Epoch 35: val_loss did not improve from 0.12278
# 11/11 [==============================] - 153s 14s/step - loss: 0.0237 - accuracy: 0.9879 - val_loss: 0.2465 - val_accuracy: 0.9143

# %% [markdown]
# # EVALUACION

# %% [markdown]
# ### Graficos de Accuracy y Loss

# %%
fig = plt.figure()
plt.plot(history.history['loss'], color='teal', label='loss')
plt.plot(history.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(history.history['accuracy'], color='teal', label='accuracy')
plt.plot(history.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ### Evaluación con datos de testing

# %%
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=combined_preprocessing_function,
    fill_mode='nearest'
)
# Crear un flujo de imágenes desde el directorio de entrenamiento
test_generator = test_datagen.flow_from_directory(
    '/UPC/Tesis/DATASET/split_data/test',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 74 images belonging to 3 classes.

# %%
# Evaluar el modelo para obtener la pérdida y la precisión (accuracy)
loss, accuracy = model.evaluate(test_generator)
print(f'Test Loss: {loss}')
print(f'Test Accuracy: {accuracy}')
# Out:
# 3/3 [==============================] - 6s 2s/step - loss: 0.3629 - accuracy: 0.8919
# Test Loss: 0.36294567584991455
# Test Accuracy: 0.8918918967247009

# %%
# Obtén las predicciones del modelo
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)  # Convierte las predicciones a etiquetas

# Obtén las etiquetas verdaderas
y_true = test_generator.classes
# Out:
# 3/3 [==============================] - 11s 1s/step

# %%
# Obtén la precisión, recall, f1-score, etc.
report = classification_report(y_true, y_pred_classes, target_names=test_generator.class_indices.keys())
print(report)
# Out:
#                  precision    recall  f1-score   support
#
# Pterigión_Grave       1.00      0.92      0.96        39
#  Pterigión_Leve       0.91      0.91      0.91        23
#   Sin_Pterigión       0.80      1.00      0.89        12
#
#        accuracy                           0.93        74
#       macro avg       0.90      0.95      0.92        74
#    weighted avg       0.94      0.93      0.93        74

# %%
# Obtén la matriz de confusión
conf_matrix = confusion_matrix(y_true, y_pred_classes)

# Calcula la sensibilidad y especificidad para cada clase
sensitivity = np.diag(conf_matrix) / np.sum(conf_matrix, axis = 1)
specificity = (np.sum(conf_matrix, axis=0) - np.diag(conf_matrix)) / (np.sum(conf_matrix, axis=0) + np.sum(conf_matrix, axis=1) - 2*np.diag(conf_matrix))

print(f'Sensitivity for each class: {sensitivity}')
print(f'Specificity for each class: {specificity}')
# Out:
# Sensitivity for each class: [0.92307692 0.91304348 1.        ]
# Specificity for each class: [0.  0.5 1. ]

# %%
num_classes = len(np.unique(y_true))  # número de clases
VP = np.diag(conf_matrix)  # Verdaderos Positivos son la diagonal de la matriz de confusión

VN = np.sum(conf_matrix) - np.sum(conf_matrix, axis=0) - np.sum(conf_matrix, axis=1) + VP  # Verdaderos Negativos
FP = np.sum(conf_matrix, axis=0) - VP  # Falsos Positivos
FN = np.sum(conf_matrix, axis=1) - VP  # Falsos Negativos

for i in range(num_classes):
    print(f'Clase {i}: VP={VP[i]}, VN={VN[i]}, FP={FP[i]}, FN={FN[i]}')
# Out:
# Clase 0: VP=36, VN=35, FP=0, FN=3
# Clase 1: VP=21, VN=49, FP=2, FN=2
# Clase 2: VP=12, VN=59, FP=3, FN=0

# %%
plt.figure(figsize=(10,10))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=test_generator.class_indices.keys(),
            yticklabels=test_generator.class_indices.keys())
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# # GUARDAR EL MODELO

# %%
model_json = model.to_json()
with open(model_json_name,"w") as json_file:
    json_file.write(model_json)

# %%
with open(model_json_name, 'r') as json_file:
    json_savedModel= json_file.read()

# Cargamos la arquitectura del modelo
model = tf.keras.models.model_from_json(json_savedModel)
model.load_weights(model_weights_file_name)
model.compile(optimizer = adam, loss = "categorical_crossentropy", metrics = ["accuracy"])

# %% [markdown]
# # DESPLEGAR EL MODELO

# %%
def deploy(directory, model_file, model_version):
    MODEL_DIR = directory
    version = model_version

    # Juntamos el directorio del temp model con la versión elegida
    # El resultado será = '\tmp\version number'
    export_path = os.path.join(MODEL_DIR, version)
    print('export_path = {}\n'.format(export_path))

    # Guardemos el modelo con saved_model.save
    # Si el directorio existe, debemos borrarlo con '!rm'
    # rm elimina cada fichero especificado usando la consola de comandos.

    if os.path.isdir(export_path):
        print('\nAlready saved a model, cleaning up\n')
        # !rm -r {export_path}

    tf.saved_model.save(model_file, export_path)

    os.environ["MODEL_DIR"] = MODEL_DIR
